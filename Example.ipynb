# %%
a = 10
print (a)
# Out:
# 10

# %%
import funny_sentences as fs
import markovify

# %%
with open('Unix_ansi.txt') as f:
    unix = f.read()

# %%
with open('merged_tolstoy_ansi.txt') as f:
    wap = f.read()

# %%
text_m = markovify.Text(unix+wap)

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Ilya\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
inst = fs.FunnySentences(unix, wap)

# %%
inst.learn()
# Out:
#              precision    recall  f1-score   support
#
#      coding       0.98      0.98      0.98      1969
#   testament       0.98      0.98      0.98      2218
#
# avg / total       0.98      0.98      0.98      4187
#
# 0.9770718891807977

# %%
inst.gen_funny(text_m.make_sentence, 120)
# Out:
# ['И как в часах пуще всего надо объяснить, что мог исчезнуть сам народ, и во всех версиях UNIX.',
#  'либо услуг ядра, он делает не для народа, а народ прикладывается потому, что оно должно быть то же.',
#  'Только любящий брата не имеет права лишать жизни или отвергнуть ее.',
#  'Каждый сегмент хранит в себе доверие к истине.',
#  'Вера же эта привлекает к себе рабочих, боятся и ненавидят — и вам будет отправлено уведомление по электрон% ной почте.',
#  'чить дополнительные возможности этого канала, которые могут возникнуть между вами, то всё-таки все те правительственные учреждения, которые выгодны для них.',
#  'Но всему есть предел, и люди эти находятся в настоящее время выделяются сети класса С, то ос!',
#  'цию wakeup помещает в очередь чтения потока, который должен быть ужасный умственный упадок людей нашего времени, откинув веру в это время диск успеет совершить оборот на некоторый угол.',
# ...
